# %%
#%pip install eth-ape

# %%
# %pip install ape-vyper
# Out:
# ...
#   Using cached vvm-0.2.1-py3-none-any.whl (11 kB)
# ...
#   Attempting uninstall: vvm
#     Found existing installation: vvm 0.3.2
#     Uninstalling vvm-0.3.2:
#       Successfully uninstalled vvm-0.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# titanoboa 0.2.5 requires vvm>=0.3.2, but you have vvm 0.2.1 which is incompatible.
# ...
#
# [notice] A new release of pip available: 22.3 -> 24.3.1
# [notice] To update, run: /Users/georgekellerman/github/raidollardesign/simulations/venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# APE
# brownian motion datasets in test cases
# https://github.com/smolquants/ape-risk?tab=readme-ov-file


#vyper stablecoin
#https://github.com/rafael-abuawad/bobc-stablecoin.git

# %%
from ape import project

contract = project.get_contract("engine")
# Out:
# INFO:     Compiling using Vyper compiler '0.4.0'.
# Input:
# 	contracts/.ipynb_checkpoints/PIController-checkpoint.vy
# 	contracts/PIController.vy
# ---------------------------------------------------------------------------
# VyperError                                Traceback (most recent call last)
# File ~/github/raidollardesign/simulations/venv/lib/python3.11/site-packages/ape_vyper/compiler/_versions/base.py:88, in BaseVyperCompiler.compile(self, vyper_version, settings, import_map, compiler_data, project)
#      87 try:
# ---> 88     result = vvm_compile_standard(input_json, **comp_kwargs)
#      89 except VyperError as err:
#
# File ~/github/raidollardesign/simulations/venv/lib/python3.11/site-packages/vvm/main.py:205, in compile_standard(input_data, base_path, vyper_binary, vyper_version)
#     198         error_message = "\n".join(
#     199             tuple(
#     200                 error.get("formattedMessage") or error["message"]
#    (...)
#     203             )
# ...
